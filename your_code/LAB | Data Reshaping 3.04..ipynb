# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# your answer here
import pandas as pd
import numpy as np

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`.

# %%
# your answer here


employee = pd.read_csv("Employee.csv")
employee
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### What's the mean salary by department?
# Hint : There are 2 ways to do it - one way is with groupby and the other way is with pivot tables. Do it both ways.

# %%
# Method 1
# your answer here

employee.groupby('Department').agg({'Salary':np.mean}).reset_index().head()
# Out:
#   Department  Salary
# 0         HR   45.00
# 1         IT   48.75
# 2      Sales   55.00

# %%
employee.pivot_table(index= ['Department'], values = ['Salary'], aggfunc = ['mean']).reset_index()
# Out:
#   Department   mean
#              Salary
# 0         HR  45.00
# 1         IT  48.75
# 2      Sales  55.00

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title.

# %%
# Method 2
# your answer here
employee.pivot_table(index= ['Department','Title'], values = ['Salary'], aggfunc = ['mean']).reset_index()
# Out:
#   Department      Title   mean
#                         Salary
# 0         HR         VP   70.0
# 1         HR    analyst   32.5
# 2         IT         VP   70.0
# 3         IT    analyst   32.5
# 4         IT  associate   60.0
# 5      Sales  associate   55.0

# %%
# your answer here
employee.groupby(['Department','Title']).agg({'Salary':np.mean}).reset_index().head()
# Out:
#   Department      Title  Salary
# 0         HR         VP    70.0
# 1         HR    analyst    32.5
# 2         IT         VP    70.0
# 3         IT    analyst    32.5
# 4         IT  associate    60.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table.
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
# your answer here
employee.pivot_table(index= ['Years','Title'], values = ['Salary']).reset_index()
# Out:
#    Years      Title  Salary
# 0      1    analyst      35
# 1      2    analyst      30
# 2      2  associate      55
# 3      3  associate      55
# 4      4    analyst      35
# 5      7  associate      60
# 6      8         VP      70

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title.

# %%
# your answer here

employee.pivot_table(index= ['Title','Department'], values = ['Salary','Name'], aggfunc = {'Salary':['mean'],'Name':'nunique'}).reset_index()
# Out:
#        Title Department    Name Salary
#                         nunique   mean
# 0         VP         HR       1   70.0
# 1         VP         IT       1   70.0
# 2    analyst         HR       2   32.5
# 3    analyst         IT       2   32.5
# 4  associate         IT       1   60.0
# 5  associate      Sales       2   55.0

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median, minimum, maximum and standard deviation. Comment your results.

# %%
# your answer here

employee.pivot_table(index= ['Title','Department'], values = ['Salary'], aggfunc = ['median','max','min','std']).reset_index()
# Out:
#        Title Department median    max    min       std
#                         Salary Salary Salary    Salary
# 0         VP         HR   70.0     70     70       NaN
# 1         VP         IT   70.0     70     70       NaN
# 2    analyst         HR   32.5     35     30  3.535534
# 3    analyst         IT   32.5     35     30  3.535534
# 4  associate         IT   60.0     60     60       NaN
# 5  associate      Sales   55.0     55     55  0.000000

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
# your answer here
employee.pivot_table(index= ['Title','Department'], values = ['Salary'], aggfunc = ['median','max','min','std']).reset_index().fillna(0)
# Out:
#        Title Department median    max    min       std
#                         Salary Salary Salary    Salary
# 0         VP         HR   70.0     70     70  0.000000
# 1         VP         IT   70.0     70     70  0.000000
# 2    analyst         HR   32.5     35     30  3.535534
# 3    analyst         IT   32.5     35     30  3.535534
# 4  associate         IT   60.0     60     60  0.000000
# 5  associate      Sales   55.0     55     55  0.000000

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
# your answer here
employee.pivot_table(index= ['Department'], values = ['Salary','Name'], aggfunc = {'Salary':'sum','Name':'nunique'}).reset_index()
# Out:
#   Department  Name  Salary
# 0         HR     3     135
# 1         IT     4     195
# 2      Sales     2     110

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary.

# %%
# your answer here

employee.pivot_table(index= ['Title','Department'], values = ['Salary','Years'], aggfunc = {'Salary':'mean','Years':'sum'}).reset_index()
# Out:
#        Title Department  Salary  Years
# 0         VP         HR    70.0      8
# 1         VP         IT    70.0      8
# 2    analyst         HR    32.5      6
# 3    analyst         IT    32.5      3
# 4  associate         IT    60.0      7
# 5  associate      Sales    55.0      5

# %% [markdown]
# ### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table.
#
# Hint: Write a custom function.

# %%
# your answer here
